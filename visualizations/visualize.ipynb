# %% [markdown]
# # 1D Cratering Data Anlysis
# ### Fergus Horrobin

# %%
# %load_ext autoreload
# %autoreload 1

# %%
'''Import Libraries'''
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
from scipy.optimize import curve_fit
sp.init_printing()
# %matplotlib inline

# %aimport visualization
# %aimport plots
# Out:
# /mnt/scratch-lustre/fhorrobin/venv-2.7.13/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
'''Global Variables for working directory'''
# The main folder (stores results for given value of gamma)
UPPER = "../res/gamma5_3"
GAMMA = 5./3.

folders = visualization.get_folders(UPPER)
all_files = visualization.file_list(folders, UPPER)

# %% [markdown]
# ## Working with a Single File

# %%
folder = 'res_0.4'
fname = visualization.full_path(UPPER, folder, '/snapshot_12.h5')
hydro_vars = visualization.read_hydro_variables(fname, GAMMA)

# %%
plots.plot_hydro_vars(hydro_vars)

# %%
plots.plot_velocity_data(UPPER, folder)

# %% [markdown]
# ## Working with all the files

# %%
ax = plots.many_shock_front(7, all_files, UPPER, GAMMA)
ax[1].set_ylim(-4, 2)
pass

# %%
poly = plots.plot_breakout_velocity(folders, UPPER)

# %%
poly[1]
# Out:
# 0.5634059050882133

# %% [markdown]
# ## Scaling
#
# So we conclude for $\gamma = 5/3$ we have a relation as:
#
# $$ \log v_b = 0.56 \log I_w - 0.21  $$
#
# $$ v_b \propto I_w^{0.56} \approx I_w^{3/5} $$
